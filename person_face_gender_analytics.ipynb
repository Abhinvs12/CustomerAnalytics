# %%
import pandas as pd

# %%
df = pd.read_csv("dataset/person_face_gender.csv")

# %%
df
# Out:
#     Counter              In_time  Gender
# 0         0  2023-04-23 00:09:00    Male
# 1         1  2023-04-23 00:11:00    Male
# 2         2  2023-04-23 00:13:00    Male
# 3         3  2023-04-23 00:15:00    Male
# 4         4  2023-04-23 00:17:00  Female
# 5         5  2023-04-23 00:19:00  Female
# 6         6  2023-04-23 00:21:00  Female
# 7         7  2023-04-23 00:23:00  Female
# 8         8  2023-04-23 00:25:00  Female
# 9         9  2023-04-23 00:27:00    Male
# 10       10  2023-04-23 00:29:00  Female
# 11       11  2023-04-23 00:31:00  Female
# 12       12  2023-04-23 00:33:00  Female
# 13       13  2023-04-23 00:35:00  Female
# 14       14  2023-04-23 00:37:00  Female
# 15       15  2023-04-23 00:39:00    Male
# 16       16  2023-04-23 00:41:00  Female
# 17       17  2023-04-23 00:43:00  Female
# 18       18  2023-04-23 00:45:00    Male
# 19       19  2023-04-23 00:47:00  Female
# 20       20  2023-04-23 00:49:00  Female
# 21       20  2023-04-23 00:09:00  Female
# 22       20  2023-04-23 00:14:00  Female
# 23       21  2023-04-23 00:19:00    Male
# 24       22  2023-04-23 00:24:00    Male
# 25       23  2023-04-23 00:29:00    Male
# 26       24  2023-04-23 00:34:00  Female
# 27       25  2023-04-23 00:39:00    Male
# 28       26  2023-04-23 00:44:00    Male
# 29       27  2023-04-23 00:49:00  Female

# %%
import seaborn as sns
import matplotlib.pyplot as plt
 
 
sns.countplot(data=df, x='Gender')
plt.show()

# %%
df['In_date']=df['In_time'].str.split(expand=True)[0]

# %%
df['In_time']=df['In_time'].str.split(expand=True)[1]

# %%
df = df.reindex(['Counter','Gender','In_time','In_date'], axis=1)

# %%
filtered_df = df.loc[(df['In_time'] >= '00:09:00')& (df['In_time'] < '00:12:00')]

# %%
filtered_df
# Out:
#     Counter  Gender   In_time     In_date
# 0         0    Male  00:09:00  2023-04-23
# 1         1    Male  00:11:00  2023-04-23
# 21       20  Female  00:09:00  2023-04-23

# %%
import seaborn as sns
import matplotlib.pyplot as plt
 
 
sns.countplot(data=filtered_df, x='Gender')
plt.show()
